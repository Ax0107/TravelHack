# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('DataSetMain.xlsx')

# %%
type_food_mapper = {
    "All Inclusive" : "AI",
    "AIP" : "AI",
    "UAI" : "UAI",
    "Ultra All Exclusive" : "UAI",
    "RO" : "RO",
    "Premium All Inclusive" : "AI",
    "AXI" : "UAI",
    "BB" : "BB",
    "FB" : "FB",
    "PALAZZO ALL INCLUSIVE" : "AI",
    "EAI" : "UAI",
    "HB" : "HB",
    "BB+FB" : "FB",
    "DAI" : "UAI",
    "HEA" : "AI",
    "Полный пансион" : "FB",
    "0" : "RO",
    "HB (завтрак+ужин)" : "HB",
    "NULL" : "NULL",
    "HCI" : "HB",
    "Half Board Platinum" : "HB+",
    "All Inclusive Dine Around" : "AI",
    "FB + Оздоровит. путевка" : "FB",
    "MAI" : "UAI",
    "По программе" : "PROGRAM",
    "Basic All Inclusive" : "AI",
    "HB + Оздоровит. путевка" : "HB+",
    "All Inclusive Ultra" : "UAI",
    "Soft All Inclusive" : "AI",
    "Breakfast" : "BB",
    "BB Continental" : "BB",
    "DDAI" : "UAI",
    "A'LA CARTE ALL INCLUSIVE" : "AI",
    "ULTRA ALL INCLUSIVE PLUS" : "UAI",
    "SC" : "RO",
    "FB+" : "FB+",
    "ALL IN CONCEPT" : "AI",
    "Ultimate All Inclusive" : "UAI",
    "PREMIUM ULTRA ALL INCLUSIVE" : "UAI",
    "AIS" : "AI",
    "AI Light" : "AI",
    "Light All Inclusive" : "AI",
    "PRIVILEGED LIFE" : "FB",
    "PREMIER ULTRA ALL INCLUSIVE" : "UAI",
    "FB AI" : "AI",
    "HB+" : "HB+",
    "PREMIUM ALA CARTE ALL INCLUSIVE" : "UAI",
    "HB Plus" : "HB+",
    "Full Board Treatment Relax" : "FB",
    "Golden All Inclusive" : "AI",
    "Half board + drinks" : "HB+",
    "Platinum Plan All inclusive" : "UAI",
    "Half Board Dine Around" : "HB",
    "AI NON ALCOHOL" : "AI",
    "Diamond AI" : "AI",
    "FB + Лечение" : "FB",
    "HB (завтрак+обед)" : "HB",
    "Завтрак" : "BB",
    "LUXME" : "AI",
    "LAI" : "UAI",
    "FBp - Завтрак, обед, ужин (Premium)" : "FB",
    "FAI" : "AI",
    "SUPERIOR ALL INCLUSIVE" : "UAI",
    "All Inclusive Premium" : "AI",
    "Only Bed" : "RO",
    "BB + Оздоровит. путевка" : "BB",
    "PRE.AI.LIFE STYLE" : "AI",
    "As Per Program" : "PROGRAM",
    "ULTRA ALL INCLUSIVE WITH HIGH LEVEL" : "UAI",
    "HB Beverage" : "HB",
    "LAI FB" : "AI",
    "Emerald All Inclusive" : "AI",
    "Все включено СЕМЕЙНЫЙ" : "FB",
    "Полный пансион + Лечение" : "FB",
    "FB Beverage" : "FB",
    "HB AI" : "AI",
    "Full Board + drinks" : "FB+",
    "Serenity Plan" : "PROGRAM",
    "All Inclusive Aqua" : "AI",
    "Полный Пансион (шведский стол) + Отдых" : "FB",
    "Limited all Inclusive" : "AI",
    "Bed Only" : "RO",
    "Full Board Premium" : "FB",
    "FB + Общетерапевт.путевка" : "FB",
    "Gold All Inclusive" : "AI",
    "BB Пляжный" : "BB",
    "Pure Indulgence Dine Around" : "AI",
    "Bed And Breakfast Plus" : "BB",
    "FB + Антистресс" : "FB",
    "Без питания" : "RO",
    "Полный Пансион+Отдых бассейн с термотерапией" : "FB",
    "BB+HB" : "HB",
    "Crystal Package" : "AI",
    "Island Plan All Inclusive" : "AI",
    "Full Dine Around All Inclusive" : "AI",
    "VARU ALL INCLUSIVE" : "AI",
    "Оздоровительная." : "FB",
    "FB + Оздоровительная" : "FB",
    "Half Board Premium" : "HB",
    "LAI HB" : "AI",
    "FB + Отдых" : "FB",
    "Super All Inclusive" : "AI",
    "RO + Оздоровительная курсовка" : "RO",
    "PR - Завтрак, ужин (Premium)" : "HB",
    "HBT" : "HB",
    "Полупансион (завтрак+ужин)" : "HB",
    "FBT" : "FB",
    "Half Board Beach" : "HB",
    "RO + Оздоровительная путевка" : "RO",
    "По программе +" : "PROGRAM",
    "All inclusive Style" : "AI",
    "HB + Лечение" : "HB",
    "All Inc Ultra Luxury" : "UAI",
    "Полный пансион+ Общетерапевтическая Лайт" : "FB",
    "All Inclusive Lite" : "AI",
    "Полный пансион + Общетерапевтическая с Мацестой" : "FB",
    "Half Board Treatment Relax" : "HB",
    "Al + лечение" : "AI",
    "Полный пансион + Общетерапевтическая без Мацесты" : "FB",
    "Все включено ПЛЯЖНЫЙ" : "AI",
    "Полный пансион + путевка Курортная" : "FB",
    "Полный Пансион + Смарт путевка" : "FB",
    "Полный Пансион + Серебряный возраст" : "FB",
    "FB ресторан «Алтай» + Лечебная путевка" : "FB",
    "FB + Gala Dinner" : "FB",
}

# df['Тип питания'] = df['Тип питания'].map(type_food_mapper)

# %%
stars_mapper = {
    "4*" : "4",
    "5*" : "5",
    "3*" : "3",
    "3*-4*" : "3.5",
    "HV1" : "HV1",
    "2*" : "2",
    "0" : "0",
    "3*+" : "3.5",
    "-" : "0",
    "apt" : "APT",
    "NULL" : "NULL",
    "HV" : "HV1",
    "4*+" : "4.5",
    "Без звёзд" : "0",
    "1*" : "1",
    "2*super" : "2.5",
    "2*+" : "2.5",
    "HV2" : "HV2",
    "5* Deluxe" : "5.5",
    "Std Apt" : "APT",
    "BOUTIQUE" : "5",
    "Guest House" : "0",
    "5*+" : "5.5",
    "2*-3*" : "2.5",
    "3*super" : "3.5",
    "S-CLASS" : "4.5",
    "cat B" : "3",
    "SC" : "4.5",
    "4*-5*" : "4.5",
    "cat A" : "4"
}

# df['Звездность'] = df['Звездность'].map(stars_mapper)

# %%
# Out:
#        Пол День рождения  Возраст клиента  Заявка №    Дата бронирования  \
# 0  мужской    2018-08-28              2.0    4803671 2021-02-07 20:44:00
# 1  мужской    1991-04-25             29.0    4803671 2021-02-07 20:44:00
# 2  мужской    1980-11-05             40.0    4803915 2021-02-08 09:03:00
# 3  мужской    2013-02-27              8.0    4806034 2021-02-08 19:46:00
# 4  мужской    1968-10-06             52.0    4806034 2021-02-08 19:46:00
#
#   Дата начала тура   Год  Ночей       Вид тура Тип заявки  ... Младенцы  \
# 0       2021-05-04  2021     12  Пляжный отдых      Пакет  ...        0
# 1       2021-05-04  2021     12  Пляжный отдых      Пакет  ...        0
# 2       2021-03-04  2021      6  Пляжный отдых      Пакет  ...        0
# 3       2021-10-09  2021     11  Пляжный отдых      Пакет  ...        0
# 4       2021-10-09  2021     11  Пляжный отдых      Пакет  ...        0
#
#   Звездность  Состав группы (Заявка) (Заявка)  Сумма в $   Наименование тура  \
# ...

# %%
data.dtypes
# Out:
# Пол                                        object
# День рождения                      datetime64[ns]
# Возраст клиента                           float64
# Заявка №                                    int64
# Дата бронирования                  datetime64[ns]
# Дата начала тура                   datetime64[ns]
# Год                                         int64
# Ночей                                       int64
# Вид тура                                   object
# Тип заявки                                 object
# Страна тура                                object
# Регион отеля                               object
# Туристов                                    int64
# Туристы, взрослые                           int64
# Туристы, дети                               int64
# Младенцы                                    int64
# Звездность                                 object
# Состав группы (Заявка) (Заявка)            object
# Сумма в $                                 float64
# ...

# %%
def delete_double(column):
  return re.sub(r'[(]\w+[)]','',column).strip()
data = data.rename(delete_double, axis='columns')
data.head()
# Out:
#        Пол День рождения  Возраст клиента  Заявка №   Дата бронирования  \
# 0  мужской    2018-08-28              2.0   4803671 2021-02-07 20:44:00
# 1  мужской    1991-04-25             29.0   4803671 2021-02-07 20:44:00
# 2  мужской    1980-11-05             40.0   4803915 2021-02-08 09:03:00
# 3  мужской    2013-02-27              8.0   4806034 2021-02-08 19:46:00
# 4  мужской    1968-10-06             52.0   4806034 2021-02-08 19:46:00
#
#   Дата начала тура   Год  Ночей       Вид тура Тип заявки  ... Младенцы  \
# 0       2021-05-04  2021     12  Пляжный отдых      Пакет  ...        0
# 1       2021-05-04  2021     12  Пляжный отдых      Пакет  ...        0
# 2       2021-03-04  2021      6  Пляжный отдых      Пакет  ...        0
# 3       2021-10-09  2021     11  Пляжный отдых      Пакет  ...        0
# 4       2021-10-09  2021     11  Пляжный отдых      Пакет  ...        0
#
#   Звездность  Состав группы  Сумма в $   Наименование тура  ИД клиента  \
# ...

# %%
data['Ночей'].value_counts()
# Out:
# 7      51285
# 10     29833
# 9      22665
# 8      21473
# 11     16559
# 14     16184
# 12     11836
# 6      10913
# 13      7947
# 5       5718
# 4       4340
# 3       2708
# 15      2169
# 21      1242
# 16       787
# 17       682
# 18       659
# 2        582
# 20       577
# 0        484
# 19       331
# 1        203
# 22       104
# 28        86
# 25        50
# 23        47
# 27        36
# 24        13
# 29        13
# 30        11
# 26         8
# 34         8
# 217        7
# 88         7
# 45         6
# 42         5
# 54         4
# 48         4
# 228        4
# 35         3
# 82         3
# 245        3
# 38         2
# 32         2
# 155        2
# 50         1
# 59         1
# 73         1
# 31         1
# Name: Ночей, dtype: int64

# %%
sum(data.isnull().sum(1) > 20)
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Пол                       0
# День рождения           429
# Возраст клиента         429
# Заявка №                  0
# Дата бронирования         0
# Дата начала тура          0
# Год                       0
# Ночей                     0
# Вид тура                940
# Тип заявки                0
# Страна тура             940
# Регион отеля         110421
# Туристов                  0
# Туристы, взрослые         0
# Туристы, дети             0
# Младенцы                  0
# Звездность            99347
# Состав группы             0
# Сумма в $                 0
# Наименование тура         0
# ИД клиента                0
# Глубина продаж            0
# Тип питания           99347
# Город Отеля          110421
# Город отправления         0
# dtype: int64

# %%
data['ИД клиента'] = data['ИД клиента'].astype(int)

# %%
data['День рождения'].dt.year.hist()

# %%
# data['День рождения'] = data['День рождения'].apply(lambda x: np.NaN if x.year < 1930 else x)
# data['День рождения'].fillna(data['День рождения'].quantile(0.5, interpolation="midpoint"), inplace=True)
# день рождения можно не обрабатывать

# %%
plt.scatter(new_data["Age"], new_data["Overall"])

# %%
data['Возраст клиента'].value_counts()
# Out:
# 37.0    5572
# 36.0    5524
# 34.0    5424
# 35.0    5391
# 33.0    5336
#         ...
# 88.0       8
# 89.0       5
# 87.0       4
# 91.0       2
# 90.0       2
# Name: Возраст клиента, Length: 93, dtype: int64

# %%
data['Возраст клиента'].fillna(data['Возраст клиента'].median(), inplace=True)
data['Возраст клиента'] = data['Возраст клиента'].astype(int)

# %%
# data['День рождения'].fillna(data['День рождения'].quantile(0.5, interpolation="midpoint"), inplace=True)
# data['Возраст клиента'].fillna(data['Возраст клиента'].median(), inplace=True)

# %%
data['Вид тура'].value_counts()
# Out:
# Пляжный отдых                   183080
# VIP                               8449
# Наземное обслуживание             4877
# Горнолыжные туры                  3748
# Экскурсионный тур                 2761
# Городские туры                    2316
# Нестандартные туры                1237
# Only Tickets                       697
# Круиз                              287
# Лечебные туры                      251
# Комбинированный тур                220
# Индивидуальный туризм              211
# Рекламный Тур                      115
# Отдых                              102
# Оздоровительный/SPA Отдых           94
# Продажа дополнительных услуг        82
# Динамический пакет                  33
# Отдых в горах                       29
# Ж/д туры                            24
# Отдых на озерах                     23
# Туры выходного дня                  22
# Автобусные туры                     11
# Name: Вид тура, dtype: int64

# %%
data[data['Вид тура'].isnull()]
# Out:
#             Пол День рождения  Возраст клиента  Заявка №   Дата бронирования  \
# 2186    мужской    1987-05-11               33   3017456 2018-01-24 21:26:00
# 2339    мужской    1957-02-25               64   3065363 2018-03-27 12:40:00
# 2628    мужской    1973-01-25               48   3170464 2018-06-13 21:56:00
# 2652    мужской    1983-07-05               37   3412496 2019-01-10 14:37:00
# 2724    мужской    1969-04-23               51   3437126 2019-01-25 20:18:00
# ...         ...           ...              ...       ...                 ...
# 207480  женский    1965-07-28               55   3053807 2018-03-16 20:18:00
# 207670  женский    1967-01-29               54   3419374 2019-01-15 19:04:00
# 207759  женский    1993-05-13               27   3403932 2018-12-27 19:53:00
# 207898  женский    1951-10-25               69   3102580 2018-04-26 18:52:00
# 207953  женский    1975-03-01               46   3317257 2018-09-07 21:20:00
#
# ...

# %%
data[data['Вид тура'].isnull()]['Тип заявки'].value_counts()
# Out:
# Индивидуальный тур    819
# Билеты регулярные     101
# VIP тур                13
# Пакет                   6
# Инфотур                 1
# Name: Тип заявки, dtype: int64

# %%
data[data['Вид тура'].isnull()][data['Тип заявки'] == 'Билеты регулярные']
# Out:
# /Users/andrewbelyaev/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             Пол День рождения  Возраст клиента  Заявка №   Дата бронирования  \
# 3478    мужской    2005-06-24               15   3649278 2019-04-29 14:42:00
# 3479    мужской    2004-05-28               16   3649278 2019-04-29 14:42:00
# 3480    мужской    2005-03-14               16   3649278 2019-04-29 14:42:00
# 3481    мужской    2005-02-13               16   3649278 2019-04-29 14:42:00
# 3482    мужской    2004-10-29               16   3649278 2019-04-29 14:42:00
# ...         ...           ...              ...       ...                 ...
# 115408  женский    1961-03-31               59   3360682 2018-10-18 16:53:00
# 115409  женский    1980-06-06               40   3360682 2018-10-18 16:53:00
# ...

# %%
data['Вид тура'] = data['Вид тура'].fillna(data['Вид тура'].value_counts().keys()[0])

# %%
len(data['Страна тура'].unique())
# Out:
# 53

# %%
data['Наименование тура'].value_counts()[-90:-50]
# Out:
# Рекламный тур в Янтарный край с TUI MOW GDS                         1
# Infotour Италия – Швейцария – Княжество Лихтенштейн MOW             1
# Гранд тур "Вся Карелия", 3 дня (Карелия без перелета)               1
# Israel TLV SVX GDS                                                  1
# Прага Стандарт CEK GDS                                              1
# Infotour Spain-Andorra S18                                          1
# Thailand Pattaya ROV GDS                                            1
# Мир Диснея (без авиаперелета)                                       1
# Infotour Tunisia S18 MOW                                            1
# Infotour Thailand Phuket MOW 20.10-28.10                            1
# UAE TUI FAM trip UFA                                                1
# Infotour Croatia LED                                                1
# France Paris ROV GDS                                                1
# ...

# %%
data[data['Вид тура'].isnull()]
# Out:
#             Пол День рождения  Возраст клиента   Заявка №   Дата бронирования  \
# 1055        NaN    1985-05-16             35.0        NaN                 NaT
# 1056        NaN    1985-05-16             35.0        NaN                 NaT
# 2186    мужской    1987-05-11             33.0  3017456.0 2018-01-24 21:26:00
# 2339    мужской    1957-02-25             64.0  3065363.0 2018-03-27 12:40:00
# 2628    мужской    1973-01-25             48.0  3170464.0 2018-06-13 21:56:00
# ...         ...           ...              ...        ...                 ...
# 207480  женский    1965-07-28             55.0  3053807.0 2018-03-16 20:18:00
# 207670  женский    1967-01-29             54.0  3419374.0 2019-01-15 19:04:00
# 207759  женский    1993-05-13             27.0  3403932.0 2018-12-27 19:53:00
# 207898  женский    1951-10-25             69.0  3102580.0 2018-04-26 18:52:00
# 207953  женский    1975-03-01             46.0  3317257.0 2018-09-07 21:20:00
#
# ...

# %%
codes = pd.read_csv('airport-codes_csv.csv')

# %%
codes = codes[codes.iata_code.notnull()][]

# %%
# Out:
#       ident            type                         name  elevation_ft  \
# 223     03N   small_airport               Utirik Airport           4.0
# 440    07FA   small_airport      Ocean Reef Club Airport           8.0
# 594     0AK   small_airport        Pilot Station Airport         305.0
# 673    0CO2   small_airport        Crested Butte Airpark        8980.0
# 1088   0TE7   small_airport            LBJ Ranch Airport        1515.0
# ...     ...             ...                          ...           ...
# 55530  ZYTL   large_airport           Zhoushuizi Airport         107.0
# 55531  ZYTN  medium_airport    Tonghua Sanyuanpu Airport        1200.0
# 55532  ZYTX   large_airport              Taoxian Airport         198.0
# 55533  ZYYJ  medium_airport  Yanji Chaoyangchuan Airport         624.0
# 55534  ZYYK  medium_airport        Yingkou Lanqi Airport           0.0
#
#       continent iso_country iso_region   municipality gps_code iata_code  \
# ...

# %%
data.columns
# Out:
# Index(['Пол', 'День рождения', 'Возраст клиента', 'Заявка №',
#        'Дата бронирования', 'Дата начала тура', 'Год', 'Ночей', 'Вид тура',
#        'Тип заявки', 'Страна тура', 'Регион отеля', 'Туристов',
#        'Туристы, взрослые', 'Туристы, дети', 'Младенцы', 'Звездность',
#        'Состав группы', 'Сумма в $', 'Наименование тура', 'ИД клиента',
#        'Глубина продаж', 'Тип питания', 'Город Отеля', 'Город отправления'],
#       dtype='object')

# %%
df = pd.DataFrame(columns = ["ИД клиента", "ИД друга", "Заявка друга"])
df
# Out:
# Empty DataFrame
# Columns: [ИД клиента, ИД друга, Заявка друга]
# Index: []

# %%
data[data['ИД клиента'].isin(friends)][data['ИД клиента'] != client_id]['ИД клиента']
# Out:
# /Users/andrewbelyaev/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 0        4197428
# 85309    4197432
# 85310    4197434
# Name: ИД клиента, dtype: int64

# %%
Friend_df = pd.DataFrame(columns = data.columns.insert(0,'ID'))
number_of_friends = list()
client_id = 4197429
# for client in tqdm(data['ИД клиента'].unique()):
bids = data[data['ИД клиента'] == client_id]['Заявка №']
number = 0
df = pd.DataFrame(columns = ["ИД клиента", "ИД друга", "Заявка друга"])
for bid in bids:
    friends = data[data['Заявка №']== bid]['ИД клиента'].tolist()
    df = df.append(data[data['ИД клиента'].isin(friends)][data['ИД клиента'] != client_id]['ИД клиента'])
number += len(df)  
df['ID'] = client_id
Friend_df = Friend_df.append(df)
number_of_friends.append(number)
# Out:
# /Users/andrewbelyaev/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # Remove the CWD from sys.path while we load stuff.

# %%
Friend_df
# Out:
#                  ID  Пол День рождения Возраст клиента Заявка №  \
# ИД клиента  4197429  NaN           NaN             NaN      NaN
#
#            Дата бронирования Дата начала тура  Год Ночей Вид тура  ...  \
# ИД клиента               NaN              NaN  NaN   NaN      NaN  ...
#
#            ИД клиента Глубина продаж Тип питания Город Отеля  \
# ИД клиента        NaN            NaN         NaN         NaN
#
#            Город отправления ИД друга Заявка друга          0      85309  \
# ИД клиента               NaN      NaN          NaN  4197428.0  4197432.0
#
#                 85310
# ИД клиента  4197434.0
#
# [1 rows x 31 columns]

# %%
df
# Out:
#             ID      Пол День рождения  Возраст клиента Заявка №  \
# 0      4197429  мужской    2018-08-28              2.0  4803671
# 85309  4197429  женский    2016-02-21              5.0  4803671
# 85310  4197429  женский    1987-12-21             33.0  4803671
#
#         Дата бронирования Дата начала тура   Год Ночей       Вид тура  ...  \
# 0     2021-02-07 20:44:00       2021-05-04  2021    12  Пляжный отдых  ...
# 85309 2021-02-07 20:44:00       2021-05-04  2021    12  Пляжный отдых  ...
# 85310 2021-02-07 20:44:00       2021-05-04  2021    12  Пляжный отдых  ...
#
#       Младенцы Звездность Состав группы Сумма в $   Наименование тура  \
# 0            0         4*         Семья   1718.64  Turkey Antalya LED
# 85309        0         4*         Семья   1718.64  Turkey Antalya LED
# 85310        0         4*         Семья   1718.64  Turkey Antalya LED
#
#       ИД клиента Глубина продаж    Тип питания Город Отеля  Город отправления
# ...

# %%
print(len(data['ИД клиента'].unique()), data.shape[0])
# Out:
# 193276 209609

# %%
data['Наименование тура'].apply(lambda x: x.split(' ')[0]).unique()
# Out:
# array(['Turkey', 'Cyprus', 'Байкал', 'Абхазия', 'TUI', 'Россия', 'UAE',
#        'Maldives', 'Montenegro', 'Greece', 'Продажа',
#        'Домбай-Приэльбрусье', 'Круиз', 'Беларусь', 'SL', 'Калининград',
#        'Золотой', 'Стамбул', 'Tunisia', 'Spain', 'Классическая',
#        '*Индивидуальный', 'Thailand', 'Bulgaria', 'Italy', 'Albania',
#        'Калабрия', 'Dominican', 'Jordan', 'Римские', 'Croatia', 'Israel',
#        'Finland', 'Andorra', 'Бонжорно', 'Прага', 'Cuba', 'Czech',
#        'Лазурный', 'Испания:', 'Sri', 'Sweden', 'Vietnam', 'Новая',
#        'Китай', 'Combitour', 'Georgia', 'Убуд', 'OLD_Indonesia',
#        'Чехия-Лечебные', 'Кострома', 'France', 'Portugal', 'old', 'В',
#        'Летние', 'Незабываемые', 'Москва', 'Мурманск', 'Weekend',
#        'Hungary', 'о.Бали', 'Latvia', 'Чехия-Горные', 'Геленджик',
#        'SPA-отели', 'Austria', 'Новый', 'Италия', 'На', 'Великий',
#        'Экскурсионный', 'Санкт-Петербург', 'Классический', 'Япония:',
# ...

# %%
data['Наименование тура'].apply(lambda x: x.split(' ')[0]).unique()
# Out:
# array(['Turkey', 'Cyprus', 'Байкал', 'Абхазия', 'TUI', 'Россия', 'UAE',
#        'Maldives', 'Montenegro', 'Greece', 'Продажа',
#        'Домбай-Приэльбрусье', 'Круиз', 'Беларусь', 'SL', 'Калининград',
#        'Золотой', 'Стамбул', 'Tunisia', 'Spain', 'Классическая',
#        '*Индивидуальный', 'Thailand', 'Bulgaria', 'Italy', 'Albania',
#        'Калабрия', 'Dominican', 'Jordan', 'Римские', 'Croatia', 'Israel',
#        'Finland', 'Andorra', 'Бонжорно', 'Прага', 'Cuba', 'Czech',
#        'Лазурный', 'Испания:', 'Sri', 'Sweden', 'Vietnam', 'Новая',
#        'Китай', 'Combitour', 'Georgia', 'Убуд', 'OLD_Indonesia',
#        'Чехия-Лечебные', 'Кострома', 'France', 'Portugal', 'old', 'В',
#        'Летние', 'Незабываемые', 'Москва', 'Мурманск', 'Weekend',
#        'Hungary', 'о.Бали', 'Latvia', 'Чехия-Горные', 'Геленджик',
#        'SPA-отели', 'Austria', 'Новый', 'Италия', 'На', 'Великий',
#        'Экскурсионный', 'Санкт-Петербург', 'Классический', 'Япония:',
# ...

# %%
data['Страна тура'].value_counts()
# Out:
# Турция                      124842
# Кипр                         17868
# Россия                        9538
# Испания                       7582
# ОАЭ                           7472
# Греция                        6672
# Италия                        5722
# Черногория                    5333
# Тунис                         3632
# Болгария                      3601
# Таиланд                       3595
# Иордания                      2056
# Хорватия                      1791
# Абхазия                       1615
# Израиль                       1342
# Андорра                       1009
# Мальдивы                       885
# Чехия                          701
# Куба                           565
# Доминиканская Республика       518
# Шри-Ланка                      316
# Албания                        288
# Круизы                         287
# Индонезия                      274
# Франция                        271
# Венгрия                        136
# Грузия                         135
# ...

# %%
data['Год'].value_counts()
# Out:
# 2019    103547
# 2018     58994
# 2020     28025
# 2021     18865
# 2017       177
# 2022         1
# Name: Год, dtype: int64

# %%
pd.to_datetime(data['Дата начала тура']).dt.month
# Out:
# 0         2021
# 1         2021
# 2         2021
# 3         2021
# 4         2021
#           ...
# 209604    2021
# 209605    2021
# 209606    2021
# 209607    2020
# 209608    2021
# Name: Дата начала тура, Length: 209609, dtype: int64

# %%
data['Дата начала тура'] = pd.to_datetime(data['Дата начала тура'])

# %%
data['Дата бронирования'].dt.month
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
#          ..
# 209604    1
# 209605    1
# 209606    1
# 209607    8
# 209608    1
# Name: Дата бронирования, Length: 209609, dtype: int64

# %%
dist = data[data['Год'] == (2019 or 2018)].groupby(by=[data['Дата бронирования'].dt.month, 'Страна тура'])['Пол'].count()
pd.DataFrame(dist)
# Out:
#                                   Пол
# Дата бронирования Страна тура
# 1                 Абхазия          22
#                   Австрия           9
#                   Андорра         100
#                   Болгария        173
#                   Великобритания    1
# ...                               ...
# 12                Франция          12
#                   Хорватия         16
#                   Черногория       35
#                   Чехия            15
#                   Шри-Ланка         8
#
# [402 rows x 1 columns]

# %%
data.

# %%
# Out:
#      Дата бронирования               Страна тура  Количество
# 327                 10                    Польша           1
# 99                   4                  Беларусь           1
# 94                   3               Южная Корея           1
# 168                  6  Доминиканская Республика           1
# 19                   1                    Латвия           1
# ..                 ...                       ...         ...
# 120                  4                    Турция        6553
# 260                  8                    Турция        6820
# 87                   3                    Турция        6854
# 185                  6                    Турция        7819
# 220                  7                    Турция        9357
#
# [402 rows x 3 columns]

# %%
dist = pd.DataFrame(dist)
# dist.reset_index()
# dist = dist['Страна тура']
# dist.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-c7a3ba731d76> in <module>
# ----> 1 dist = pd.DataFrame(dist).reset_index()
#       2 # dist.reset_index()
#       3 # dist = dist['Страна тура']
#       4 # dist.head()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4602                 # to ndarray and maybe infer different dtype
#    4603                 level_values = _maybe_casted_values(lev, lab)
# -> 4604                 new_obj.insert(0, name, level_values)
#    4605
#    4606         new_obj.index = new_index
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3494         self._ensure_valid_index(value)
#    3495         value = self._sanitize_column(column, value, broadcast=False)
# ...

# %%
# Out:
#                                Страна тура
# Дата бронирования Страна тура
# 1                 Турция              3593
#                   Кипр                 485
#                   ОАЭ                  369
#                   Италия               310
#                   Испания              231

# %%
dist = pd.DataFrame(dist)
dist.rename(columns = {'Страна тура': })
dist.head()
# Out:
#                               Страна тура
# Дата начала тура Страна тура
# 1                ОАЭ                  400
#                  Италия               227
#                  Таиланд              201
#                  Иордания             170
#                  Андорра              167

# %%
plt.plot(dist)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a number, not 'tuple'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-2882331e94d5> in <module>
# ----> 1 plt.plot(dist)
#
# /usr/local/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1646         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1647         for line in lines:
# ...

# %%
data[data['Год'] == 2019].groupby(by=data['Дата бронирования'].dt.month)

# %%
pd.to_datetime(data['Дата начала тура'])
# Out:
# dtype('<M8[ns]')
